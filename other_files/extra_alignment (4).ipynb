# %%
from difflib import SequenceMatcher

# %%
#GT = ['', 'den', '27', 'July']
#OCR = ['', 'Bruffél,', 'den', 'z', '7', 'July']
#GT = ['', 'Lauarens', 'te', 'verlaten', 'Binnen', 'de', 'voorsz']
#OCR =['', 'Laurens', 'te', 'vei', 'laten', 'Binnen', 'de', 'vooriz']
#GT = ['', 'Den', '21', 'deser', 'zijn', 'de', 'Franse', 'voor', 'Arien', 'gekomen,', 'onder', 'den', 'Maerschalck', "d\\'Humieres,", 'ende', 'hadden', "d\\'onse", 'gedwongen', 'het', 'Fort', 'St']
#OCR = ['', 'Den', 'defer', 'zijn', 'de', 'anfevoor', 'Arien', 'geicomen', 'onder', 'den']
GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['Valencijn,', 'den', 'July']
#OCR = ['Vakncijn,', 'den', 'j', '->', 'July']

print(SequenceMatcher(None, GT[2], OCR[4]).ratio())
print(SequenceMatcher(None, OCR[4], GT[2]).ratio())
# Out:
# 0.0
# 0.0

# %%
print(SequenceMatcher(None, '', '').ratio())
# Out:
# 1.0

# %%
max(len(GT), len(OCR))
max([GT, OCR], key=len)
# Out:
# ['',
#  'Stad',
#  'is',
#  'een',
#  'seer',
#  'out',
#  'Soldaet',
#  'tot',
#  'Gouverneur',
#  'gemaeckt,',
#  'genaemt',
#  'Comte',
#  'de',
#  'Broné,',
#  'en',
#  'is',
#  'maer',
#  'een',
#  'advenue',
#  'om',
#  'aen',
#  'te',
#  'konnen',
#  'komen,',
#  'en',
#  'buyten',
#  'dat',
#  'altemael',
#  'Moeras,',
#  'soo',
#  'dat',
#  'lang',
#  'sal',
#  'konnen',
#  'houden;',
#  'Ondertusschen',
#  'is',
#  'den',
#  'Hertogh',
#  'van',
#  'Villa',
#  'Hermosa',
#  'met',
#  '16000',
#  'man',
#  'in',
#  'marsch,',
#  'als',
#  'mede',
#  'den',
#  'Velt-Maerschalck',
#  'Waldeck,',
#  'om',
#  'de',
#  'selve',
#  'plaets',
#  "t\\'ontsetten"]

# %%
#GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen']
GT = ['', '', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,']
OCR = ['Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt']

from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)

for i in range(len(longest_list)):
    print('i:', i)
    # check if there is a direct match:
    try:
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            continue
        else:
            # check if there is a match with the word before in OCR:
            try:
                if SequenceMatcher(None, GT[i], OCR[i-1]).ratio() > 0.65:
                    print('GT:', GT[i])
                    print('OCR:', OCR[i-1])
                    print('matched one lower')
                    OCR.insert(i-1, '')
            except:
                pass
            # check if there is a match with the word after in OCR:
            try:
                if SequenceMatcher(None, GT[i], OCR[i+1]).ratio() > 0.65:
                    print('GT:', GT[i])
                    print('OCR:', OCR[i+1])
                    print('matched one further')
                    GT.insert(i, '')
            except:
                pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    # if there is no match at all
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    
    # look for closest match:
     
print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))
# Out:
# i: 0
# GT:
# OCR: Stad
# not matched
# i: 1
# GT:
# OCR: is
# not matched
# i: 2
# GT: Stad
# OCR: een
# not matched
# i: 3
# GT: is
# OCR: feer
# not matched
# i: 4
# GT: een
# OCR: out
# not matched
# i: 5
# GT: seer
# OCR: Soldaet
# not matched
# i: 6
# GT: out
# OCR: tot
# matched
# i: 7
# GT: Soldaet
# OCR: Gouverneur
# not matched
# i: 8
# GT: tot
# OCR: gemaeckt
# not matched
# i: 9
# GT: Gouverneur
# OCR:
# not matched
# i: 10
# GT: gemaeckt,
# OCR:
# not matched
# new GT: ['', '', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,']
# new OCR: ['Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', '', '']
# 11 11

# %%
print(GT.index('Velt-Maerschalck'))
print(OCR.index('Velt-Maerfchalck'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-80654cc5f49b> in <module>
# ----> 1 print(GT.index('Velt-Maerschalck'))
#       2 print(OCR.index('Velt-Maerfchalck'))
#
# ValueError: 'Velt-Maerschalck' is not in list

# %%
# find errors:
error_list = []

for i in range(len(GT)):
    error = []
    if GT[i] != OCR[i]:
        if OCR[i] != '':
            print(GT[i], OCR[i])
            error.append(OCR[i])
            error.append(GT[i])
            error.append(i)
            error_list.append(error)
    
print(error_list)

# %%
GT = ['', 'Lauarens', 'te', 'verlaten', 'Binnen', 'de', 'voorsz']
OCR =['', 'Laurens', 'te', 'vei', 'laten', 'Binnen', 'de', 'vooriz']

# %%
lijstje = [1,2,4,5,6]
lijstje.insert(2, 3)
print(lijstje)

# %%
SequenceMatcher(None, 'een', 'aen').ratio()

# %%
# forwards loop

#GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,']
#OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen']
#GT = ['Valencijn,', 'den', 'July']
#OCR = ['Vakncijn,', 'den', 'j', '->', 'July']
#GT = ['', '', 'Stad', 'is', 'een', 'seer', 'out', 'EXTRA', 'EXTRA', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,']
#OCR = ['Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt']
#GT = ['konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['', 'konnen', 'aen', '', 'dat', '', '', '', '', '', '', 'komen,', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#sentGT = "Het Leger onder den Velt-Maerschal den Grave van Waldeck, heeft eenighe dagen tot Wals Waveren"
#sentOCR = "Het Leger onderden Velt-Maerfchal den Grave van Waldeck, heeft eenighedagen tot Wals Waveren"
#sentGT = "Laurens te vei laten Binnen de vooriz"
#sentOCR = "Lauarens te verlaten Binnen de voorsz"
sentGT ="Stad is een seer out Soldaet tot Gouverneur gemaeckt, genaemt Comte de Broné, en is maer een advenue om aen te konnen komen, en buyten dat altemael Moeras, soo dat lang sal konnen houden; Ondertusschen is den Hertogh van Villa Hermosa met 16000 man in marsch, als mede den Velt-Maerschalck Waldeck, om de selve plaets t\\'ontsetten"
sentOCR = "Stad is een feer out Soldaet tot Gouverneur gemaeckt genaemt Comte de brooé, en is macr een auvenue om om aen te konnen komen, en buyten dat altemael MoerasJ, foo dat lang fal konnen houden; Ondertuffchen is den Hcrtogh van Villa liermofamet ióooomanin marfch , als mede den Velt-Maerfchalck Waldeck, om de felve t'ontfettcn"
#sentGT = " Passagiers uyt gedachte Leger in\\'t sluyten hier aengekomen, rapporteren, dat het Leger dese morgen naer \\'t slaen vande reveille was opgebroocken, ende naer Vilvoorden gemarcheert"
#sentOCR = "gckomen, rapporteren , dat hei Leger ekfe morgen naer 'tllacn vande reveille was opgebroocken , ende naer Vilvoorden gemarcheci t"
#sentGT = "Gisteren begon men op het Bastion la Reyne te canonneren, dat geloove in een dag of twee zijn bekomst sal ontfangen'"
#sentOCR = "Gift er en begon men op her Baftion la Reyne te canonneren, dat geloovc in een dag of twee zijn bekomft fal om fangen'"
#sentGT = "Den Graef van Hoorn heeft op heden aen sijne Hoogheyt verhaelt, dat sedert den 22 tot heden toe, gedaen zijn 80 schoten uyt heele, en 8800 uyt halve Cartouwen, en 128 uyt 12 Ponders"
#sentOCR = "Den Graefvan Hoorn heeftop heden aen lijne Hoogheyt verhaclt, dat federt den 22 tot Leden toe , gedaen zijn So fchoten uyt hcclc, en Hbo uyt halve Cartouwen, en IxBuvt:irondcrs"

GT = sentGT.split(' ')
OCR = sentOCR.split(' ')

#GT = ['', 'Wy', 'hebben', 'dese', 'nacht', 'wel', 'geavanceert,', 'en', 'canonneren', 'wederom', 'seer', 'sterck,', 'en', 'zijn', 'gisteren', 'de', 'resterende', 'twee', 'heele', 'Cartouwen', 'en', '3', 'halve', 'op', 'de', 'Batteryen,', 'nevens', '4', 'Mortieren', 'gebracht']
#OCR =['', 'Wy', 'hebben', "clel'e-", 'nacht', 'veePgeavancecrt,', 'en', 'canofincren', 'wederom', 'léer', '(lerck', ',en', 'ziin', 'gift,ren', 'de', 'refterende', 'twee', 'heele', 'Car-ouwen', 'en', '3', 'halve', 'op', 'de', 'Batteryen,', 'nevens4', 'lylortieren', 'gebracht']
#GT = ['', 'Wy', 'hebben', 'dese', 'nacht', 'wel', 'geavanceert,', 'en', 'canonneren', 'wederom', 'seer', 'sterck,']
#OCR =['', 'Wy', 'hebben', "clel'e-", 'nacht', 'veePgeavancecrt,', 'en', 'canofincren', 'wederom', 'léer', '(lerck']
#GT = ['', 'De', 'Franse', 'hebben', 'tot', 'de', 'klocke', '10', 'uren', 'niet', 'een', 'schoot', 'uyt', 'de', 'Stadt', 'gedaen,', 'tot', 'verwondering', 'van', 'een', 'yder']
#OCR = ['', 'De', 'j', 'ranfe', 'hebben', 'tot', 'de', 'kloeke', '10', 'uren', 'niet', 'een', 'fclioot', 'uyt', 'de', 'S', 'ad:', 'gedaen', ',', 'tot', 'verwondering', 'van', 'ten', ';']
#GT = ['', 'Den', '21', 'deser', 'zijn', 'de', 'Franse', '', 'voor', 'Arien', 'gekomen,', '', 'onder', 'den', '', 'Maerschalck', "d\\'Humieres,", 'ende', 'hadden', "d\\'onse", 'gedwongen', 'het', 'Fort', 'St']
#OCR = ['', 'Den', '11', 'defer', 'zijn', 'de', '', 'Fi', 'anfevoor', 'Arien', 'geicomen', ',', 'onder', 'den', 'i\\', 'aerfchalck', "d'Humicrcs,", 'ende', 'hadden', "d'onfegedwor", '', '']
#GT = ['', 'Waer', 'mede', 'Hoog', 'Mogende', 'Heeren,', '', '', 'etc']
#OCR = ['', 'Waer', 'mede', 'Hoog', 'Mogende', 'Hceien', ',', 'Bcc']
#GT = ['Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", 'sluyten', 'hier',  'aengekomen,',  'rapporteren,', 'dat', 'het', 'Leger', 'dese', 'morgen', 'naer',  "\\'t",  'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', 'ende', 'naer', 'Vilvoorden', 'gemarcheert']
#OCR = ['gckomen,', 'rapporteren', 'dat',  'hei', 'Leger', 'ekfe', 'morgen', 'naer', "'tllacn", 'vande', 'reveille',  'was', 'opgebroocken', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't']
#GT = ['', 'Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", '', 'sluyten', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', 'morgen', 'naer', "\\'t", 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
#OCR = ['', '', '', '', '', '', 'gckomen,', 'rapporteren', '', ',', '', '', '', 'dat', '', 'hei', 'Leger', 'ekfe', 'morgen', 'naer', "'tllacn", '', 'vande', 'reveille', 'was', 'opgebroocken', ',', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't'] 


from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)
min_ratio = 0.65

for i in range(len(longest_list)):
    match = False
    #i = -i-1
    print('i:', i)
    # check if there is a direct match:
    #print('GT index:', GT[i])
    #print('OCR index:', OCR[i])
    try:
        print('GT index 1:', GT[i])
        print('OCR index 1:', OCR[i])
        if OCR[i] == ' ' and GT[i] == '':
            del OCR[i]
            del GT[i]
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() >= min_ratio:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            print('new GT:', GT)
            print('new OCR:', OCR)
            match = True
            continue
        elif match == False:
            # check if there is a match with a word before in OCR:
            try:
                for j in range(1,3):
                    if i-j >= 0:
                        if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() >= min_ratio:
                            print('GT:', GT[i])
                            print('OCR:', OCR[i-j])
                            print(f'matched {j} lower')
                            if not (GT[i] == '' and OCR[i-j] == ''):
                                for k in range(0,j):
                                    OCR.insert(i-j, '')
                                    print('inserted')
                                print('new GT:', GT)
                                print('new OCR:', OCR)
                                match = True
                                continue
                    if i+j <= len(OCR):          
                        if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() >= min_ratio:
                            print('GT:', GT[i])
                            print('OCR:', OCR[i+j])
                            print(f'matched {j} further')
                            if not (GT[i] == '' and OCR[i+j] == ''):
                                for k in range(0,j):
                                    GT.insert(i, '')
                                print('new GT:', GT)
                                print('new OCR:', OCR)
                                match = True
                                continue
            except:
                pass
            # check if there is a match with a word after in OCR:
            #try:
            #    for j in range(1,100):
            #        if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
            #            print('GT:', GT[i])
            #            print('OCR:', OCR[i+j])
            #            print(f'matched {j} further')
            #            for k in range(0,j):
            #                GT.insert(i-j, '')
            #            print('new GT:', GT)
            #            print('new OCR:', OCR)
            #            break
            #except:
            #    pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    if match == False:
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() >= 0.30:
            pass
        else:
            print('bad match')
            #OCR.insert(i, '')
            min([GT, OCR], key=len).insert(i, '')
            print('new GT:', GT)
            print('new OCR:', OCR)
            continue
    
    
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    
    print('new GT:', GT)
    print('new OCR:', OCR)
    
if len(GT) != len(OCR):
        # backwards loop

        shortest_list = min([GT, OCR], key=len)
        longest_list = max([GT, OCR], key=len)

        for i in range(len(longest_list)):
            i = -i-1
      
            try:

                if (OCR[i] == '') ^ (GT[i] == ''):

                    continue
                if OCR[i] == ' ' and GT[i] == '':
                    del OCR[i]
                    del GT[i]
                if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
     
                    continue
                else:
                    # check if there is a match with a word before in OCR:
                    try:
                        for j in range(1,3):
                            if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() > 0.65:
    
                                for k in range(0,j):
                                    if i+j != 0:
                                        GT.insert(i+j, '')
                                    else: 
                                        GT.append('')

                                break
                            if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:

                                for k in range(0,j):
                                    GT.insert(i, '')

                                break
                    except:
                        pass

            except IndexError:
                min([GT, OCR], key=len).append('')

            # if there is no match:
            if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.50:
                pass
            else:
                if (OCR[i] == '') or (GT[i] == ''):
                    continue
                else:
                    min([GT, OCR], key=len).insert(i+1, '')
            

    
print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))
#print(GT.index('Soldaet'))
#print(OCR.index('Soldaet'))
#print('VM:', GT.index('Velt-Maerschalck'))
#print('VM:',OCR.index('Velt-Maerfchalck'))
#print('mede:', GT.index('mede'))
#print('mede:', OCR.index('mede'))
print('woord:', GT.index('Velt-Maerschalck'))
print('woord:', OCR.index('Velt-Maerfchalck'))
# Out:
# i: 0
# GT index 1: Stad
# OCR index 1: Stad
# GT: Stad
# OCR: Stad
# matched
# new GT: ['Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
# ...

# %%
# backwards loop

#GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,']
#OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen']
#GT = ['Valencijn,', 'den', 'July']
#OCR = ['Vakncijn,', 'den', 'j', '->', 'July']
#GT = ['', '', 'Stad', 'is', 'een', 'seer', 'out', 'EXTRA', 'EXTRA', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,']
#OCR = ['Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt']
#GT = ['', '', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,']
#OCR = ['Stad', 'is', 'een', 'feer', 'out', 'EXTRA', 'EXTRA',  'Soldaet', 'tot', 'Gouverneur', 'gemaeckt']
#GT = ['konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['', 'konnen', 'aen', '', 'dat', '', '', '', '', '', '', 'komen,', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
#GT = ['Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', '', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', '', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
#OCR = ['Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'MoerasJ,', 'foo', 'dat', 'lang', 'fal', 'konnen', 'houden;', 'Ondertuffchen', 'is', 'den', 'Hcrtogh', 'van', 'Villa', 'liermofamet', '', '', 'ióooomanin', '', 'marfch', ',', 'als', 'mede', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'felve', "t'ontfettcn"]
#GT = ['', 'Den', '21', 'deser', 'zijn', 'de', 'Franse', '', 'voor', 'Arien', 'gekomen,', '', 'onder', 'den', '', 'Maerschalck', "d\\'Humieres,", 'ende', 'hadden', "d\\'onse", 'gedwongen', 'het', 'Fort', 'St']
#OCR = ['', 'Den', '11', 'defer', 'zijn', 'de', '', 'Fi', 'anfevoor', 'Arien', 'geicomen', ',', 'onder', 'den', 'i\\', 'aerfchalck', "d'Humicrcs,", 'ende', 'hadden', "d'onfegedwor", '', '', '']
GT = ['', 'Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", '', 'sluyten', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', 'morgen', 'naer', "\\'t", 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
OCR = ['', '', '', '', '', '', 'gckomen,', 'rapporteren', '', ',', '', '', '', 'dat', '', 'hei', 'Leger', 'ekfe', 'morgen', 'naer', "'tllacn", '', 'vande', 'reveille', 'was', 'opgebroocken', ',', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't'] 
    
from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)

for i in range(len(longest_list)):
    i = -i-1
    print('i:', i)
    # check if there is a direct match:
    #print('GT index:', GT[i])
    #print('OCR index:', OCR[i])
    try:
        print('GT index:', GT[i])
        print('OCR index:', OCR[i])
        if OCR[i] == '' or GT[i] == '':
            print('new GT:', GT)
            print('new OCR:', OCR)
            continue
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            print('new GT:', GT)
            print('new OCR:', OCR)
            continue
        else:
            # check if there is a match with a word before in OCR:
            try:
                for j in range(1,3):
                    if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i-j])
                        print(f'matched {j} lower')
                        for k in range(0,j):
                            OCR.insert(i-j, '')
                            print('inserted')
                        print('new GT:', GT)
                        print('new OCR:', OCR)
                        break
                    if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i+j])
                        print(f'matched {j} further')
                        for k in range(0,j):
                            GT.insert(i, '')
                        print('new GT:', GT)
                        print('new OCR:', OCR)
                        break
            except:
                pass
            # check if there is a match with a word after in OCR:
            #try:
            #    for j in range(1,100):
            #        if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
            #            print('GT:', GT[i])
            #            print('OCR:', OCR[i+j])
            #            print(f'matched {j} further')
            #            for k in range(0,j):
            #                GT.insert(i-j, '')
            #            print('new GT:', GT)
            #            print('new OCR:', OCR)
            #            break
            #except:
            #    pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    # if there is no match:
    if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.50:
        pass
    else:
        print('bad match')
        #OCR.insert(i, '')
        min([GT, OCR], key=len).insert(i+1, '')# works if the '' is added to OCR
        print("' ' inserted")
        print('new GT:', GT)
        print('new OCR:', OCR)
    
    
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    
    print('new GT:', GT)
    print('new OCR:', OCR)
    

print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))
#print(GT.index('Soldaet'))
#print(OCR.index('Soldaet'))
#print('VM:', GT.index('Velt-Maerschalck'))
#print('VM:',OCR.index('Velt-Maerfchalck'))
print('Vilvoorden:', GT.index('Vilvoorden'))
print('Vilvoorden:', OCR.index('Vilvoorden'))
# Out:
# i: -1
# GT index:
# OCR index: t
# new GT: ['', 'Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", '', 'sluyten', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', 'morgen', 'naer', "\\'t", 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
# new OCR: ['', '', '', '', '', '', 'gckomen,', 'rapporteren', '', ',', '', '', '', 'dat', '', 'hei', 'Leger', 'ekfe', 'morgen', 'naer', "'tllacn", '', 'vande', 'reveille', 'was', 'opgebroocken', ',', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't']
# i: -2
# GT index: gemarcheert
# OCR index: gemarcheci
# GT: gemarcheert
# OCR: gemarcheci
# matched
# new GT: ['', 'Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", '', 'sluyten', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', 'morgen', 'naer', "\\'t", 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
# ...

# %%
print(GT.index('Velt-Maerschalck'))
print(OCR.index('Velt-Maerfchalck'))
# advenue = 49. 63
# maerschalk = 86, 80

# %%
for num in range(10, -1, -1) :
    print (num)

# %%
GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]

from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)
difference = len(longest_list) - len(shortest_list)
for i in range(0, difference):
    min([GT, OCR], key=len).insert(i, '')
print(len(GT), len(OCR))
print(len(longest_list))

for i in range(len(longest_list)-1, -1, -1):
    print('i', GT[i])
    # check if there is a direct match:
    try:
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            continue
        else:
            # check if there is a match with a word before in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i-j])
                        print(f'matched {j} lower')
                        for k in range(1,j):
                            OCR.insert(i-j, '')
                        break
            except:
                pass
            # check if there is a match with a word after in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i+j])
                        print(f'matched {j} further')
                        for k in range(1,j):
                            GT.insert(i-j, '')
                        break
            except:
                pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    # if there is no match at all
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    
    print('new GT:', GT)
    print('new OCR:', OCR)
     
print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))

print(GT.index('Velt-Maerschalck'))
print(OCR.index('Velt-Maerfchalck'))

# %%
len(OCR)
OCR[56]

# %%
GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]
new_GT = GT
new_OCR = OCR


from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)

for i in range(len(longest_list)):
    #GT_word = GT[i]
    #OCR_word = OCR[i]
    # where to find the GT word in the new_GT
    new_GT.index(GT[i])
    new_OCR.index(GT[i])
    # check if there is a direct match:
    try:
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            continue
        else:
            # check if there is a match with a word before in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i-j])
                        print(f'matched {j} lower')
                        for k in range(1,j):
                            OCR.insert(i-j, '')
                        break
            except:
                pass
            # check if there is a match with a word after in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i+j])
                        print(f'matched {j} further')
                        for k in range(1,j):
                            GT.insert(i-j, '')
                        break
            except:
                pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    # if there is no match at all
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    
    print('new GT:', GT)
    print('new OCR:', OCR)
     
print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))

# %%
GT = ['', 'Stad', 'is', 'een', 'seer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt,', 'genaemt', 'Comte', 'de', 'Broné,', 'en', 'is', 'maer', 'een', 'advenue', 'om', 'aen', 'te', 'konnen', 'komen,', 'en', 'buyten', 'dat', 'altemael', 'Moeras,', 'soo', 'dat', 'lang', 'sal', 'konnen', 'houden;', 'Ondertusschen', 'is', 'den', 'Hertogh', 'van', 'Villa', 'Hermosa', 'met', '16000', 'man', 'in', 'marsch,', 'als', 'mede', 'den', 'Velt-Maerschalck', 'Waldeck,', 'om', 'de', 'selve', 'plaets', "t\\'ontsetten"]
OCR = ['', 'Stad', 'is', 'een', 'feer', 'out', 'Soldaet', 'tot', 'Gouverneur', 'gemaeckt', 'genaemt', 'Comte', 'de', 'brooé,', 'en', 'is', 'macr', 'een', 'auvenue', 'om', 'konnen', 'aen', 'dat', 'komen,', 'konnen', 'en', 'van', 'marfch', 'als', 'fal', 'mede', 'den', 'den', 'Velt-Maerfchalck', 'Waldeck,', 'om', 'de', 'den', 'mede', 'den', 'felve', "t'ontfettcn"]

from difflib import SequenceMatcher

shortest_list = min([GT, OCR], key=len)
longest_list = max([GT, OCR], key=len)

i = 0
while i < len(max([GT, OCR], key=len)):
    # check if there is a direct match:
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    try:
        if SequenceMatcher(None, GT[i], OCR[i]).ratio() > 0.65:
            print('GT:', GT[i])
            print('OCR:', OCR[i])
            print('matched')
            i += 1
            continue
        else:
            # check if there is a match with a word before in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i-j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i-j])
                        print(f'matched {j} lower')
                        for k in range(1,j):
                            OCR.insert(i-j, '')
                        i += (j+1)
                        break
            except:
                pass
            # check if there is a match with a word after in OCR:
            try:
                for j in range(1,100):
                    if SequenceMatcher(None, GT[i], OCR[i+j]).ratio() > 0.65:
                        print('GT:', GT[i])
                        print('OCR:', OCR[i+j])
                        print(f'matched {j} further')
                        for k in range(1,j):
                            GT.insert(i-j, '')
                        i += (j+1)
                        break
            except:
                pass
    except IndexError:
        min([GT, OCR], key=len).append('')
    
    # if there is no match at all
    print('GT:', GT[i])
    print('OCR:', OCR[i])
    print('not matched')
    i += 1
    
    print('new GT:', GT)
    print('new OCR:', OCR)
    

print('new GT:', GT)
print('new OCR:', OCR)
print(len(GT), len(OCR))

# %%
# measure alignment quality
# good alignment. dubbed good
#GT = ['', 'Wy', 'hebben', 'dese', 'nacht', 'wel', 'geavanceert,', 'en', 'canonneren', 'wederom', 'seer', 'sterck,', 'en', 'zijn', 'gisteren', 'de', 'resterende', 'twee', 'heele', 'Cartouwen', 'en', '3', 'halve', 'op', 'de', 'Batteryen,', 'nevens', '4', 'Mortieren', 'gebracht']
#OCR = ['', 'Wy', 'hebben', "clel'e-", 'nacht', '', 'veePgeavancecrt,', 'en', 'canofincren', 'wederom', 'léer', '(lerck', ',en', 'ziin', 'gift,ren', 'de', 'refterende', 'twee', 'heele', 'Car-ouwen', 'en', '3', 'halve', 'op', 'de', 'Batteryen,', 'nevens4', '', 'lylortieren', 'gebracht']

# bad alignment. dubbed bad
GT = ['', 'Passagiers', 'uyt', 'gedachte', 'Legher', "in\\'t", '', 'sluyten', '', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', '', 'morgen', 'naer', "\\'t", '', 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', '', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
OCR = ['', '', '', '', '', '', 'gckomen,', '', 'rapporteren', '', ',', '', '', '', 'dat', '', 'hei', 'Legher', '', 'ekfe', 'morgen', 'naer', '', "'tllacn", '', 'vande', 'reveille', 'was', 'opgebroocken', ',', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't']

# good alignment. dubbed good.
#GT = ['', 'Het', 'Leger', 'onder', '', 'den', 'Velt-Maerschal', 'den', 'Grave', 'van', 'Waldeck,', 'heeft', 'eenighe', 'dagen', 'tot', 'Wals', 'Waveren,', 'vier', 'uren', 'van', 'dese', 'Stadt', 'gecampeert,', 'ende', 'werd', 'geseght', 'dat', 'heden', 'van', 'daer', 'sullen', 'opbreecken']
#OCR = ['', 'Het', 'Leger', 'onderden', '', '', 'Velt-Maerfchal', 'den', 'Grave', 'van', 'Waldeck,', 'heeft', 'eenighedagen', '', 'tot', 'Wals', 'Waveren,', 'vier', 'uren', 'van', 'defc', 'Stadt', 'gecampeert,', 'c-ndc', 'werdt', 'geftght', 'dat', 'heden', 'van', 'daer', 'lullen', 'opbreecken']

# good alignment. dubbed good
#GT = ['', "\\'s", 'middags', 'hebben', 'de', 'onse', 'seer', 'hard', '', '', 'en', 'sonder', 'op', 'houden', 'met', 'Canon', 'geschoten', 'van', '5', 'Batteryen,', '', 'soo', 'dat', 'wy', '', 'hier', 'meende', 'alles', 'over', 'hoop', 'soude', 'vallen']
#OCR = ['', "'s", 'middags', 'hebben', 'de', 'onfe', 'feer', 'barden', 'lbnder', 'op', 'houden', 'niet', '', '', '', 'Canon', 'gelchoten', 'van', '5', 'üatreryen', ',', 'foo', 'dar', 'wy', '1', '-ic-r', 'meende', 'alles', 'over', 'hoop', 'foude', 'vallen']

# good alignment. dubbed good
#GT = ['', "\\'s", 'Morgens', 'ten', '5', 'uren', 'ontstont', 'een', 'grooten', 'brandt', 'in', 'de', 'Stadt,', 'door', 'ons', 'schieten,', '', 'in', 'een', 'Hooy-berg,', '', 'en', 'duerde', 'wel', 'twee', 'uren:', 'de', 'Franse', 'dede', 'dien', 'dag', 'maer', 'twee', 'schoten,', 'en', 'wordt', 'sijne', 'Hoogheyt', 'versekert', 'datter', 'al', '30', 'Canonniers', 'zijn', 'gebleven,', '', 'waer', 'onder', 'twee', 'die', 'van', 'ons', 'zijn', 'overgeloopen']
#OCR = ['', "'s", 'Morgens', 'ten', '5', 'uren', 'ontüont', 'een', 'nooten', 'brandr', 'in', 'de', 'Stadt,', 'door', 'ons', 'fchieten', ',', 'in', 'een', 'Hooy-', 'berg,', 'en', 'duerde', 'wel', 'twee', 'uren', ':de', 'Fraiile', '', 'dededien', 'dag', 'niaer', 'twee', 'fchoten,', 'en', 'wordt', 'fijne', 'Hoogfieyt', 'verfekert', 'datter', 'al', '30', 'Canonuiers', 'zijn', 'gebleven', ',', '«ratr', 'onder', 'twee', 'die', 'van', 'ons', 'zijn', 'overgcloopen']

# good alignment
#GT = ['', 'Missive', 'van', "d\\'Heer", 'van', 'Dijckvelt,', 'aen', '', 'hare', 'Ho:', 'Mo:', '', 'NA', 'dat', 'sijne', 'Hoogheyt', 'voor', 'gisteren', 'hadde', '', '', 'geresolveert', 'de', '', 'marsch', 'voort', 'te', 'setten,', '', 'niet', 'recht', '', 'op', '', 'den', '', 'Vyant', '', 'staende', '', 'met', '', 'de', '', 'rechter', '', '', 'Vleugel', 'ontrent', 'de', 'Abdye', 'van', 'St']
#OCR = ['', '', '', '', '', '', '', ':', 'haicHo:', '', 'Mo:', 'V', '', 'dat', 'fijne', 'Hoo&héyt', 'voor', 'erareen', '', 'Kaddcgerefohex-rt', '', '', 'de', '', 'marfch', 'voort', 'te', 'letten', ',', 'niet', '', 'rterri', '', 'op', '', 'den', '', 'Vyant', '', 'ilaende', '', 'met', '', 'de', '', 'recht', 'ei', '', 'Vleugelontrent', 'de', 'Abdye', 'van', 'St']

#for i in range(len(GT)):
    #print(SequenceMatcher(None, GT[i], OCR[i]).ratio())
    #if (len(GT[i]) >= 5) or (len(OCR[i]) >= 5):
        #print(GT[i], OCR[i])
        #print(SequenceMatcher(None, GT[i], OCR[i]).ratio())
        
#print(GT.index('rapporteren,'))
#print(OCR.index('rapporteren'))

#GT_indices = []
#OCR_indices = []

# for i in range(len(GT)):
#     if (len(GT[i]) >= 5) and (GT[i] != ''):
#         for j in range(len(GT)):
#             if (OCR[i] != ''):
#                 if (SequenceMatcher(None, GT[i], OCR[j]).ratio() >= 0.75):
#                     print(GT[i], OCR[j])
#                     print('index GT:', i)
#                     GT_indices.append(i)
#                     print('index OCR:', j)
#                     OCR_indices.append(j)

min_word_length = 8 # the higher this number, the more likely a alignment will be seen as valid, thus higher chance at false positive, lower chance at false negative. 
match_ratio = 0.70
anchors_list = []
for i in range(len(GT)):
    if len(GT[i]) >= min_word_length:  
        anchors_list.append(GT[i])
    if len(OCR[i]) >= min_word_length:
        anchors_list.append(OCR[i])
print(anchors_list)


alignment_validation = True

for anchor in anchors_list:
    print('ANCHOR:', anchor)
    matches_GT = set()
    matches_OCR = set()
    match = False
    for i in range(len(GT)):
        if (SequenceMatcher(None, GT[i], anchor).ratio() >= 0.65) and (len(GT[i]) >= min_word_length or len(GT[i]) == 0):
            matches_GT.add(i)
            print('added as GT match:', GT[i])
        if SequenceMatcher(None, OCR[i], anchor).ratio() >= 0.65 and (len(OCR[i]) >= min_word_length or len(OCR[i]) == 0):
            matches_OCR.add(i)
            print('added as OCR match:', OCR[i])
    print('anchor:', anchor)
    print(matches_GT)
    print(matches_OCR)
    if matches_GT == matches_OCR:
        match = True
    if match == False:
        match = True
        points_set1 = set() # counts when the matched opposite word is '' for OCR
        points_set2 = set() # counts when the matched opposite word is '' for GT
        for index in matches_GT.difference(matches_OCR): # elements in matches_GT that are not in matches_OCR
            if OCR[index] == '':
                points_set1.add(index)
            if OCR[index] != '' and len(matches_OCR.difference(matches_GT)) != 0:
                match = False
        for index in matches_OCR.difference(matches_GT): # elements in matches_OCR that are not in matches_GT
            if GT[index] == '':
                points_set2.add(index)
            if GT[index] != '' and len(matches_GT.difference(matches_OCR)) != 0:
                match = False
        if len(points_set1.intersection(points_set2)) != 0: # if an anchor words was match in both OCR and GT with an '', it's a bad match.
            match = False
    if match == False:
        for index in (matches_GT.difference(matches_OCR)):
            index += 1
            if index in matches_OCR.difference(matches_GT):
                if (GT[index-1] == '' or OCR[index-1] == '') and (SequenceMatcher(None, GT[index], OCR[index]).ratio() >= match_ratio):
                    match = True
        for index in (matches_OCR.difference(matches_GT)):
            index += 1
            if index in matches_GT.difference(matches_OCR):
                if (GT[index] == '' or OCR[index] == '') and (SequenceMatcher(None, GT[index-1], OCR[index-1]).ratio() >= match_ratio):
                    match = True
    
    if match == False:
        alignment_validation = False
        
    print(match)

print('good alignment?', alignment_validation)
            
            
        
    


#print(sorted(GT_indices))
#print(sorted(OCR_indices))
# Out:
# ['Passagiers', 'gedachte', 'gckomen,', 'rapporteren', 'aengekomen,', 'rapporteren,', 'reveille', 'reveille', 'opgebroocken,', 'opgebroocken', 'Vilvoorden', 'Vilvoorden', 'gemarcheert', 'gemarcheci']
# ANCHOR: Passagiers
# added as GT match: Passagiers
# anchor: Passagiers
# {1}
# set()
# True
# ANCHOR: gedachte
# added as GT match: gedachte
# added as OCR match: gemarcheci
# anchor: gedachte
# {3}
# {33}
# False
# ANCHOR: gckomen,
# added as OCR match: gckomen,
# added as GT match: aengekomen,
# anchor: gckomen,
# {11}
# {6}
# True
# ANCHOR: rapporteren
# added as OCR match: rapporteren
# added as GT match: rapporteren,
# anchor: rapporteren
# {13}
# {8}
# True
# ANCHOR: aengekomen,
# added as OCR match: gckomen,
# added as GT match: aengekomen,
# anchor: aengekomen,
# {11}
# {6}
# True
# ANCHOR: rapporteren,
# added as OCR match: rapporteren
# added as GT match: rapporteren,
# anchor: rapporteren,
# {13}
# {8}
# True
# ANCHOR: reveille
# added as GT match: reveille
# ...

# %%
print(SequenceMatcher(None, 'gemarcheci', 'gedachte').ratio())
# Out:
# 0.6666666666666666

# %%
print(GT[47])
print(OCR[48])
# Out:
# Vleugel
# Vleugelontrent

# %%
# bad alignments found:
# bad alignments (dubbed bad)
# does not have same length:
GT = ['', 'Gisteren', '', '', '', '', '', 'begon', '', 'men', 'op', 'het', 'Bastion', 'la', 'Reyne', 'te', 'canonneren,', 'dat', 'geloove', 'in', 'een', 'dag', 'of', 'twee', 'zijn', 'bekomst', 'sal', '', 'ontfangen']
OCR =['', 'Gift', 'er', 'en', '', '', 'begon', '', 'men', 'op', 'her', 'Baftion', 'la', 'Reyne', 'te', 'canonneren,', 'dat', 'geloovc', 'in', 'een', 'dag', 'of', 'twee', 'zijn', 'bekomft', 'fal', 'om', 'fangen']

GT = ['', 'Passagiers', 'uyt', 'gedachte', 'Leger', "in\\'t", '', 'sluyten', '', 'hier', '', 'aengekomen,', '', 'rapporteren,', 'dat', '', 'het', 'Leger', 'dese', '', 'morgen', 'naer', "\\'t", '', 'slaen', 'vande', 'reveille', 'was', 'opgebroocken,', '', 'ende', 'naer', 'Vilvoorden', 'gemarcheert', '']
OCR = ['', '', '', '', '', '', 'gckomen,', '', 'rapporteren', '', ',', '', '', '', 'dat', '', 'hei', 'Leger', '', 'ekfe', 'morgen', 'naer', '', "'tllacn", '', 'vande', 'reveille', 'was', 'opgebroocken', ',', 'ende', 'naer', 'Vilvoorden', 'gemarcheci', 't']

GT = ['', 'Den', 'Graef', 'van', 'Hoorn', 'heeft', 'op', 'heden', 'aen', 'sijne', 'Hoogheyt', 'verhaelt,', 'dat', 'sedert', 'den', '', '22', 'tot', 'heden', '', 'toe,', '', 'gedaen', '', '', '', 'zijn', '80', '', 'schoten', '', 'uyt', 'heele,', 'en', '8800', '', 'uyt', '', 'halve', '', '', '', '', 'Cartouwen,', '', '', 'en', '128', '', 'uyt', '12', 'Ponders']
OCR = ['', '', 'Den', 'Graefvan', '', 'Hoorn', 'heeftop', '', 'heden', 'aen', 'lijne', 'Hoogheyt', 'verhaclt,', 'dat', '', 'federt', '', '', 'den', '22', '', 'tot', 'Leden', 'toe', ',', 'gedaen', '', '', 'zijn', '', 'So', '', '', '', '', 'fchoten', 'uyt', 'hcclc,', '', 'en', '', 'Hbo', 'uyt', '', 'halve', 'Cartouwen,', '', '', 'en', '', '', 'IxBuvt:irondcrs']
# heeft niet zelfde lengte. Gaat fout bij Delwich:
GT = ['', '', 'Delwich', 'sich', 'mede', 'by', 'de', 'Troupen', '(daer', 'de', 'Heer', 'Coljer', '', '', 'was)', '', '', '', 'gevoegt', 'hebbende,', '', 'maeckten', 'sich', '', '', 'na', '', '', 'een', 'vigoureuse', '', 'resistentie', '', 'van', 'St']
OCR =['', '', 'O', 'iwich', 'fich', 'mede', 'by', 'de', 'Troupen', '(daer', '', 'de', 'Heer', '', 'Coljer', 'was', ')', '', '', 'gevoeg!', '', '', 'hebbende,,', 'maeciten', '', 'fich', 'na', '', '', 'een', '', 'vi', '', "toureu'"]
# heeft niet dezelfde lengte:
GT = ['', 'In', 'de', '', 'Abdye', '', 'van', '', 'St']
OCR = ['', 'In', 'de', 'Abdye', '', 'vanSt', '']
# heeft niet dezelfde lengte:
GT = ['', '', '', '', 'Uyt', '', 'Madrid,', 'den', '30', '']
OCR = ['Uyt', 'Madrid', '', ',', '', 'den', '30', 'Jury', '']
# good alignments (dubbed bad)
